# %% [markdown]
# <a href="https://colab.research.google.com/github/SASU004/AI-ML/blob/main/data%20augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img= image.load_img('dog.jpg',target_size=(200,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
type(img)
#not a numpy array btw
# Out:
# PIL.Image.Image

# %%
datagen= ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
)

# %%
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
input_batch=img.reshape(1,200,200,3)

# %%
i =0
for output in datagen.flow(input_batch,batch_size=1,save_to_dir='preview',save_prefix='cat'):
  i=i+1
  if i==10:
    break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13449/4289845758.py in <cell line: 0>()
#       1 i =0
# ----> 2 for output in datagen.flow(input_batch,batch_size=1,save_to_dir='preview',save_prefix='cat'):
#       3   i=i+1
#       4   if i==10:
#       5     break
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in __next__(self)
#     113         # The transformation of images is not under thread lock
#     114         # so it can be done in parallel
# --> 115         return self._get_batches_of_transformed_samples(index_array)
#     116
#     117     def _get_batches_of_transformed_samples(self, index_array):
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in _get_batches_of_transformed_samples(self, index_array)
#     667                     format=self.save_format,
# ...
